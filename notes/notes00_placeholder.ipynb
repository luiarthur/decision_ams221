# %% [markdown]
# Open in [nbviewer](http://nbviewer.jupyter.org/github/luiarthur/decision_ams221/blob/master/notes/notes00_placeholder.ipynb)
# $ % Latex definitions % note: Ctrl-shfit-p for shortcuts menu \newcommand{\iid}{\overset{iid}{\sim}} \newcommand{\ind}{\overset{ind}{\sim}} \newcommand{\p}[1]{\left(#1\right)} \newcommand{\bk}[1]{\left[#1\right]} \newcommand{\bc}[1]{ \left\{#1\right\} } \newcommand{\abs}[1]{ \left|#1\right| } \newcommand{\norm}[1]{ \left|\left|#1\right|\right| } \newcommand{\E}{ \text{E} } \newcommand{\N}{ \mathcal N } \newcommand{\ds}{ \displaystyle } \newcommand{\R}{ \mathbb{R} } \newcommand{\suml}{ \sum_{i=1}^n } \newcommand{\overunderset}[3]{\overset{#1}{\underset{#2}{#3}}} $

# %% [markdown]
# Hello Arthur! Take great notes this quarter!

# %%
set.seed(0)
plot(rnorm(100))
# Out:
# plot without title
